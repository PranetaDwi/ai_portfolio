# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dfproduction = pd.read_csv('/content/drive/MyDrive/gemastiklolosyokyok/Production_Crops_Livestock_E_Asia_NOFLAG.csv', encoding='cp1252')
dfproduction

# %%
dfproduction = dfproduction.reset_index(drop=True)

# %%
dfproduction2=dfproduction.loc[(dfproduction['Area'] == 'Indonesia') & (dfproduction['Item'] == 'Rice')]
dfproduction2

# %%
dfproduction3 = dfproduction2.drop(['Area Code', 'Area Code (M49)', 'Area', 'Element Code','Element','Unit','Item Code', 'Item Code (CPC)', 'Item', 'Y1961', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y2021'], axis=1)
dfproduction3 = dfproduction3.reset_index(drop=True)
dfproduction3

# %%
dfproduction3_transposed = dfproduction3.T
dfproduction3_transposed

# %%
dfproduction3_transposed.columns=["Area_harvested_(ha)", "Yield_(hg/ha)" , "Production_(tonnes)"]

# %%
dfproduction3_transposed = dfproduction3_transposed.reset_index(drop=True)
dfproduction3_transposed

# %%
data = {'Year' :['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']}
data = pd.DataFrame(data)
data

# %%
datafiks = dfproduction3_transposed.copy()

# %%
datafiks.insert(0, 'Year', data['Year'])
datafiks

# %%
datafiks22 = datafiks.copy()

# %%
dftemperature = pd.read_csv('/content/drive/MyDrive/gemastiklolosyokyok/Annual_Surface_Temperature_Change (2).csv')
dftemperature

# %%
dftemperature2=dftemperature.loc[(dftemperature['Country'] == 'Indonesia')]
dftemperature2

# %%
dftemperature3 = dftemperature2.drop(['ObjectId', 'Country', 'ISO2', 'ISO3','Indicator','Unit','Source', 'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'F1961', 'F1962', 'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 'F1970', 'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978', 'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986', 'F1987', 'F1988', 'F1989', 'F1990', 'F2021', 'F2022'], axis=1)
dftemperature3 = dftemperature3.reset_index(drop=True)
dftemperature3

# %%
dftem3_transposed = dftemperature3.T
dftem3_transposed = dftem3_transposed.reset_index(drop=True)
dftem3_transposed.columns=["Temperature_Change"]
dftem3_transposed

# %%
datafiks22['Temperature_Change']=dftem3_transposed["Temperature_Change"]
datafiks22

# %%
dfemisi = pd.read_csv('/content/drive/MyDrive/gemastiklolosyokyok/Emissions_Totals_E_Asia_NOFLAG.csv', encoding='cp1252')
dfemisi

# %%
dfemisi2=dfemisi.loc[(dfemisi['Area'] == 'Indonesia') & (dfemisi['Item'] == 'Rice Cultivation') & (dfemisi['Element'] == 'Emissions (CH4)')]
dfemisi2
# Out:
#       Area Code Area Code (M49)       Area  Item Code              Item  \
# 3557        101            '360  Indonesia       5060  Rice Cultivation
#
#       Element Code          Element  Source Code      Source        Unit  ...  \
# 3557          7225  Emissions (CH4)         3050  FAO TIER 1  kilotonnes  ...
#
#           Y2013      Y2014      Y2015      Y2016      Y2017      Y2018  \
# 3557  2459.1191  2425.7134  2407.9535  2241.1368  2304.5652  2405.6138
#
#           Y2019      Y2020      Y2030      Y2050
# 3557  2257.6043  2253.2463  2649.3601  2654.4296
#
# [1 rows x 72 columns]

# %%
dfemisi3 = dfemisi2.drop(['Area Code', 'Area Code (M49)', 'Area', 'Element Code','Element','Unit','Item Code', 'Source Code', 'Source', 'Item', 'Y1961', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y2030', 'Y2050'], axis=1)
dfemisi3 = dfemisi3.reset_index(drop=True)
dfemisi3
# Out:
#       Y1991      Y1992    Y1993      Y1994      Y1995      Y1996      Y1997  \
# 0  2173.801  2347.5521  2328.41  2269.4259  2418.4741  2446.1647  2355.4335
#
#        Y1998      Y1999      Y2000  ...      Y2011      Y2012      Y2013  \
# 0  2480.0927  2529.3563  2493.3704  ...  2463.7705  2450.6619  2459.1191
#
#        Y2014      Y2015      Y2016      Y2017      Y2018      Y2019      Y2020
# 0  2425.7134  2407.9535  2241.1368  2304.5652  2405.6138  2257.6043  2253.2463
#
# [1 rows x 30 columns]

# %%
dfemisi3_transposed = dfemisi3.T
dfemisi3_transposed = dfemisi3_transposed.reset_index(drop=True)
dfemisi3_transposed.columns=["Emissions_CH4"]
dfemisi3_transposed

# %%
datafiks22['Emissions_CH4']=dfemisi3_transposed["Emissions_CH4"]
datafiks22

# %%
dfemisino2=dfemisi.loc[(dfemisi['Area'] == 'Indonesia') & (dfemisi['Item'] == 'Synthetic Fertilizers') & (dfemisi['Element'] == 'Emissions (N2O)')]
dfemisino3 = dfemisino2.drop(['Area Code', 'Area Code (M49)', 'Area', 'Element Code','Element','Unit','Item Code', 'Source Code', 'Source', 'Item', 'Y1961', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y2030', 'Y2050'], axis=1)
dfemisino3 = dfemisino3.reset_index(drop=True)
dfemisino3

# %%
dfemisino3_transposed = dfemisino3.T
dfemisino3_transposed = dfemisino3_transposed.reset_index(drop=True)
dfemisino3_transposed

# %%
dfemisino3_transposed.columns=["Emissions_N2O"]
datafiks22['Emissions_N2O']=dfemisino3_transposed["Emissions_N2O"]
datafiks22

# %%
datafiks22['Average_Precipitation']= [2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702, 2702]
datafiks22
# Out:
#     Year  Area_harvested_(ha)  Yield_(hg/ha)  Production_(tonnes)  \
# 0   1991           10281519.0        43465.0          44688240.00
# 1   1992           11103317.0        43446.0          48240008.00
# 2   1993           11012780.0        43750.0          48181088.00
# 3   1994           10733800.0        43453.0          46641500.00
# 4   1995           11438760.0        43487.0          49744140.00
# 5   1996           11569729.0        44168.0          51101504.00
# 6   1997           11140594.0        44322.0          49377056.00
# 7   1998           11730200.0        41974.0          49236700.00
# 8   1999           11963204.0        42519.0          50866388.00
# 9   2000           11793000.0        44007.0          51898000.00
# 10  2001           11500000.0        43879.0          50460800.00
# 11  2002           11521166.0        44691.0          51489696.00
# 12  2003           11477357.0        45426.0          52137600.00
# ...

# %%
dffer = pd.read_csv('/content/drive/MyDrive/gemastiklolosyokyok/Inputs_FertilizersNutrient_E_Asia_NOFLAG.csv', encoding='cp1252')
dffer

# %%
dffer2=dffer.loc[(dffer['Area'] == 'Indonesia') & (dffer['Element'] == 'Agricultural Use')]
dffer2
# Out:
#      Area Code Area Code (M49)       Area  Item Code  \
# 171        101            '360  Indonesia       3102
# 175        101            '360  Indonesia       3103
# 179        101            '360  Indonesia       3104
#
#                                 Item  Element Code           Element    Unit  \
# 171      Nutrient nitrogen N (total)          5157  Agricultural Use  tonnes
# 175  Nutrient phosphate P2O5 (total)          5157  Agricultural Use  tonnes
# 179      Nutrient potash K2O (total)          5157  Agricultural Use  tonnes
#
#        Y1961    Y1962  ...      Y2011       Y2012       Y2013       Y2014  \
# 171  84752.0  98558.0  ...  2933822.0  2947039.61  2791106.42  2909405.65
# 175  47278.0  46227.0  ...   579015.0  1353317.00  1009189.00  1270942.21
# 179   3960.0   4611.0  ...  1150000.0  1490000.00  1620000.00  1783264.91
#
#           Y2015       Y2016       Y2017       Y2018       Y2019       Y2020
# ...

# %%
dffer3 = dffer2.drop(['Area Code', 'Area Code (M49)', 'Area', 'Element Code','Element','Unit','Item Code','Item', 'Y1961', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', ], axis=1)
dffer3 = dffer3.reset_index(drop=True)
dffer3
# Out:
#        Y1991      Y1992      Y1993      Y1994      Y1995      Y1996  \
# 0  1551700.0  1697000.0  1557900.0  1649000.0  1844000.0  2084000.0
# 1   577700.0   593000.0   539700.0   518000.0   385200.0   331900.0
# 2   270700.0   293000.0   219400.0   300000.0   300000.0   300000.0
#
#        Y1997      Y1998      Y1999      Y2000  ...      Y2011       Y2012  \
# 0  1706600.0  2120900.0  1925500.0  1964400.0  ...  2933822.0  2947039.61
# 1   280000.0   361800.0   324000.0   263100.0  ...   579015.0  1353317.00
# 2   241000.0   245000.0   275000.0   266000.0  ...  1150000.0  1490000.00
#
#         Y2013       Y2014       Y2015       Y2016       Y2017       Y2018  \
# 0  2791106.42  2909405.65  2818598.24  2964027.98  2951991.41  3237087.26
# 1  1009189.00  1270942.21  1436735.53  1326500.78  1634953.22  1527440.11
# 2  1620000.00  1783264.91  1837166.20  1642053.64  2087754.54  2164718.02
#
#         Y2019       Y2020
# 0  2928279.43  3540990.00
# 1  1235092.23  1211224.82
# ...

# %%
dffer3_transposed = dffer3.T
dffer3_transposed = dffer3_transposed.reset_index(drop=True)
dffer3_transposed

# %%
dffer3_transposed.columns=["Nutrient_N", "Nutrient_P2O5","Nutrient_K2O"]
datafiks22['Nutrient_N']=dffer3_transposed["Nutrient_N"]
datafiks22['Nutrient_P2O5']=dffer3_transposed["Nutrient_P2O5"]
datafiks22['Nutrient_K2O']=dffer3_transposed["Nutrient_K2O"]
datafiks22
# Out:
#     Year  Area_harvested_(ha)  Yield_(hg/ha)  Production_(tonnes)  \
# 0   1991           10281519.0        43465.0          44688240.00
# 1   1992           11103317.0        43446.0          48240008.00
# 2   1993           11012780.0        43750.0          48181088.00
# 3   1994           10733800.0        43453.0          46641500.00
# 4   1995           11438760.0        43487.0          49744140.00
# 5   1996           11569729.0        44168.0          51101504.00
# 6   1997           11140594.0        44322.0          49377056.00
# 7   1998           11730200.0        41974.0          49236700.00
# 8   1999           11963204.0        42519.0          50866388.00
# 9   2000           11793000.0        44007.0          51898000.00
# 10  2001           11500000.0        43879.0          50460800.00
# 11  2002           11521166.0        44691.0          51489696.00
# 12  2003           11477357.0        45426.0          52137600.00
# ...

# %%
datafiks22.to_csv('/content/drive/MyDrive/gemastiklolosyokyok/indonesian_agriculture.csv')
